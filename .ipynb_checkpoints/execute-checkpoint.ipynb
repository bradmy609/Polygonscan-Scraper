# %%
from aggregateFuncs import get_polygonscan_tokens
import pandas as pd
from datetime import datetime
from sqlalchemy import create_engine

# %%
df = get_polygonscan_tokens()
# Out:
# Starting query loop, initial query destination:
# https://polygonscan.com/tokens
# Querying next URL:
# https://polygonscan.com/tokens?p=2
# Querying next URL:
# https://polygonscan.com/tokens?p=3
# Querying next URL:
# https://polygonscan.com/tokens?p=4
# Querying next URL:
# https://polygonscan.com/tokens?p=5
# End of pages, no next page link found within page_links!
# Querying next URL:
# None

# %%
dt = datetime.now()
date_h = dt.strftime('%y%m%d_%H')

# %%
table = 'poly' + date_h

# %%
engine = create_engine('sqlite:///polygonscan.db', echo=False)
df.to_sql(table, con=engine, if_exists='replace')

# %%
engine.execute("SELECT * FROM {} WHERE symbol = 'BNB'".format(table)).fetchall()
# Out:
# [('2', 'BNB', 'BNB', 413.04, '0.009077', 312.672218, '63835184288', '4', 1812782097, '-0.46', '2021-09-11', '04:25:34', 'https://polygonscan.com/tokens//token/0x3BA4c387f786bFEE076A58914F5Bd38d668B42c3')]

# %%
db_table = pd.read_sql("SELECT * FROM {}".format(table), con=engine)
db_table = db_table.set_index('rank')

# %%
db_table.head(15)
# Out:
#               token_name symbol         usd       btc         matic  \
# rank
# 1             Tether USD   USDT      1.0000  0.000022      0.757002
# 2                    BNB    BNB    413.0400  0.009077    312.672218
# 3              USD Coin    USDC      1.0000  0.000022      0.757002
# 4        ChainLink Token   LINK     27.2500  0.000599     20.628312
# 5               Uniswap     UNI     23.1300  0.000508     17.509463
# 6            binance-usd   BUSD      1.0000  0.000022      0.757002
# 7            Wrapped BTC   WBTC  45656.0000  1.003326  34561.695685
# 8           Theta Token   THETA      6.6100  0.000145      5.003785
# 9         Dai Stablecoin    DAI      1.0000  0.000022      0.757002
# 10       Crypto.com Coin    CRO      0.1763  0.000004      0.133496
# 11                 Aave    AAVE    324.0900  0.007122    245.336866
# 12           Graph Token    GRT      0.8385  0.000018      0.634714
# 13          Fantom Token    FTM      1.5600  0.000034      1.180924
# 14    Bitfinex LEO Token    LEO      3.0700  0.000067      2.323997
# 15                 Maker    MKR   2898.4300  0.063695   2194.118092
#
#        market_cap  holders    volume24h change%        date      time  \
# rank
# 1     69470110290  165,339  82412034037   -0.21  2021-09-11  04:25:34
# 2     63835184288        4   1812782097   -0.46  2021-09-11  04:25:34
# 3     29271011666  257,426   3036625786   -0.09  2021-09-11  04:25:34
# 4     12329488567    8,955   1477492859   -1.94  2021-09-11  04:25:34
# 5     12027813652    6,483    441476475   -0.01  2021-09-11  04:25:34
# 6     11489312495      164   3512573991    0.14  2021-09-11  04:25:34
# 7      9299807616   10,840    481498510   -1.22  2021-09-11  04:25:34
# 8      6607339567        3    382806536   -2.87  2021-09-11  04:25:34
# 9      6293002853   39,823    446351702   -0.29  2021-09-11  04:25:34
# 10     4456591169        2     57494247   -0.66  2021-09-11  04:25:34
# 11     4271939382   19,886    261328702    0.58  2021-09-11  04:25:34
# 12     4160814237      889    222357570   -0.53  2021-09-11  04:25:34
# 13     3974666962       19    806795771   -2.16  2021-09-11  04:25:34
# 14     2902552121        1      3331804   -2.46  2021-09-11  04:25:34
# 15     2613920081       70    105867143   -0.03  2021-09-11  04:25:34
#
#                                           contract_link
# rank
# 1     https://polygonscan.com/tokens//token/0xc2132d...
# 2     https://polygonscan.com/tokens//token/0x3BA4c3...
# 3     https://polygonscan.com/tokens//token/0x2791bc...
# 4     https://polygonscan.com/tokens//token/0x53e0bc...
# 5     https://polygonscan.com/tokens//token/0xb33eaa...
# 6     https://polygonscan.com/tokens//token/0xdab529...
# 7     https://polygonscan.com/tokens//token/0x1bfd67...
# 8     https://polygonscan.com/tokens//token/0xb46e0a...
# 9     https://polygonscan.com/tokens//token/0x8f3cf7...
# 10    https://polygonscan.com/tokens//token/0xada58d...
# 11    https://polygonscan.com/tokens//token/0xd6df93...
# 12    https://polygonscan.com/tokens//token/0x5fe2b5...
# 13    https://polygonscan.com/tokens//token/0xc9c1c1...
# 14    https://polygonscan.com/tokens//token/0x06d02e...
# 15    https://polygonscan.com/tokens//token/0x6f7C93...
